# %%
import pandas as pd
import numpy as np
import os
# Out:
# C:\Users\benfi\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\benfi\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
# Define the file path
file_path = 'C:\\Users\\benfi\\Defensive_Players_NFL\\data\\complete_drafted_df.csv'

# Read the CSV file into a DataFrame
complete_drafted_df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
complete_drafted_df
# Out:
#                                                     URL         School  \
# 0     https://www.sports-reference.com/cfb/players/a...     Iowa State
# 1     https://www.sports-reference.com/cfb/players/a...     Iowa State
# 2     https://www.sports-reference.com/cfb/players/a...  Florida State
# 3     https://www.sports-reference.com/cfb/players/a...     Cincinnati
# 4     https://www.sports-reference.com/cfb/players/a...        Arizona
# ...                                                 ...            ...
# 1955  https://www.sports-reference.com/cfb/players/t...           UTEP
# 1956  https://www.sports-reference.com/cfb/players/t...        Florida
# 1957  https://www.sports-reference.com/cfb/players/x...        Clemson
# 1958  https://www.sports-reference.com/cfb/players/z...        Georgia
# 1959  https://www.sports-reference.com/cfb/players/k...       Michigan
#
#           Conf     G  college_solo_tackles  college_assisted_tackle  \
# 0       Big 12  24.0                  42.0                     34.0
# 1       Big 12  24.0                 162.0                     92.0
# 2          ACC  36.0                  34.0                     41.0
# 3     Big East  34.0                  43.0                     35.0
# 4       Pac-10  46.0                 143.0                     40.0
# ...        ...   ...                   ...                      ...
# 1955      CUSA  45.0                 217.0                    174.0
# 1956       SEC  51.0                 135.0                     79.0
# 1957       ACC  61.0                  65.0                     56.0
# 1958       SEC  50.0                  28.0                     24.0
# 1959   Big Ten  44.0                  54.0                     59.0
#
#       college_total_tackles  college_tackles_for_loss  college_sk  \
# 0                      76.0                       8.0         2.5
# 1                     254.0                      17.5         3.0
# 2                      75.0                      17.5         5.5
# 3                      78.0                      17.0         7.0
# 4                     183.0                       8.5         1.0
# ...                     ...                       ...         ...
# 1955                  391.0                      35.0         8.5
# 1956                  214.0                      32.0         9.5
# 1957                  121.0                      35.0        17.5
# 1958                   52.0                       5.0         1.5
# 1959                  113.0                      10.0         4.5
#
#       college_int  ...  college_int_yds_avg  college_int_td_avg  \
# 0             0.0  ...             0.000000            0.000000
# 1             2.0  ...             0.916667            0.000000
# 2             0.0  ...             0.000000            0.000000
# 3             0.0  ...             0.000000            0.000000
# 4            15.0  ...             7.586957            0.065217
# ...           ...  ...                  ...                 ...
# 1955          2.0  ...            -0.044444            0.000000
# 1956          1.0  ...             0.294118            0.000000
# 1957          0.0  ...             0.000000            0.114754
# 1958          0.0  ...             0.000000            0.080000
# 1959          1.0  ...             0.204545            0.000000
#
#       college_passes_defended_avg  college_fumbles_recov_avg  \
# 0                        0.041667                   0.000000
# 1                        0.000000                   0.000000
# 2                        0.083333                   0.000000
# 3                        0.117647                   0.058824
# 4                        0.000000                   0.000000
# ...                           ...                        ...
# 1955                     0.333333                   0.088889
# 1956                     0.176471                   0.000000
# 1957                     0.032787                   0.327869
# 1958                     0.020000                   0.000000
# 1959                     0.000000                   0.022727
#
#       college_fumbles_recov_yds_avg  college_fumbles_recov_td_avg  \
# 0                          0.000000                      0.000000
# 1                          0.000000                      0.000000
# 2                          0.000000                      0.000000
# 3                          1.088235                      0.029412
# 4                          0.000000                      0.000000
# ...                             ...                           ...
# 1955                       0.444444                      0.022222
# 1956                       0.000000                      0.000000
# 1957                       0.000000                      0.098361
# 1958                       0.000000                      0.020000
# 1959                       0.000000                      0.000000
#
#       college_fumbles_forced_avg  drafted  position_group  power_5
# 0                       0.041667     True              DL     True
# 1                       0.000000     True              LB     True
# 2                       0.000000     True              DL     True
# 3                       0.000000     True              LB    False
# 4                       0.000000     True              DB    False
# ...                          ...      ...             ...      ...
# 1955                    0.111111     True              LB    False
# 1956                    0.039216     True              LB     True
# 1957                    0.000000     True              DL     True
# 1958                    0.000000     True              DL     True
# 1959                    0.000000     True              DL     True
#
# [1960 rows x 72 columns]

# %%
#----------------------------------------

# %%
# Exclude 2024 data
dl_df = complete_drafted_df[(complete_drafted_df['position_group'] == 'DL') & (complete_drafted_df['player_year'] < 2024)]
lb_df = complete_drafted_df[(complete_drafted_df['position_group'] == 'LB') & (complete_drafted_df['player_year'] < 2024)]
db_df = complete_drafted_df[(complete_drafted_df['position_group'] == 'DB') & (complete_drafted_df['player_year'] < 2024)]


lb_df['years_played'] = lb_df['draft_to'] - lb_df['player_year']
lb_df['years_played'] = lb_df['years_played'].replace(0, 1)  # Avoid division by zero
lb_df['carav_per_year'] = lb_df['draft_carav'] / lb_df['years_played']
lb_df['carav_per_year'].fillna(0, inplace=True)
# Out:
# C:\Users\benfi\AppData\Local\Temp/ipykernel_72452/596435513.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lb_df['years_played'] = lb_df['draft_to'] - lb_df['player_year']
# C:\Users\benfi\AppData\Local\Temp/ipykernel_72452/596435513.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lb_df['years_played'] = lb_df['years_played'].replace(0, 1)  # Avoid division by zero
# C:\Users\benfi\AppData\Local\Temp/ipykernel_72452/596435513.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lb_df['carav_per_year'] = lb_df['draft_carav'] / lb_df['years_played']
# C:\Users\benfi\AppData\Local\Temp/ipykernel_72452/596435513.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lb_df['carav_per_year'].fillna(0, inplace=True)

# %%
# Extracting the top 10 draft picks each year for the DL (Defensive Linemen) position group based on `draft_pick`
# Assuming `complete_drafted_df` is already loaded in the environment

# %%
lb_df[lb_df['player_name'] == 'Angelo Craig']
# Out:
#                                                  URL      School      Conf  \
# 3  https://www.sports-reference.com/cfb/players/a...  Cincinnati  Big East
#
#       G  college_solo_tackles  college_assisted_tackle  college_total_tackles  \
# 3  34.0                  43.0                     35.0                   78.0
#
#    college_tackles_for_loss  college_sk  college_int  ...  \
# 3                      17.0         7.0          0.0  ...
#
#    college_passes_defended_avg  college_fumbles_recov_avg  \
# 3                     0.117647                   0.058824
#
#    college_fumbles_recov_yds_avg  college_fumbles_recov_td_avg  \
# 3                       1.088235                      0.029412
#
#    college_fumbles_forced_avg  drafted  position_group  power_5  years_played  \
# 3                         0.0     True              LB    False           NaN
#
#    carav_per_year
# 3             0.0
#
# [1 rows x 74 columns]

# %%
#lb

# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from imblearn.over_sampling import SMOTE
from scipy.stats import ttest_ind
import joblib
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Fill NaN in `carav_per_year` with 0
lb_df['carav_per_year'].fillna(0, inplace=True)

# Define features and impute missing values for the LB position group
lb_features = ['combine_shuttle', 'combine_broad', 'combine_vertical', 'combine_forty',
               'college_total_tackles_avg', 'college_tackles_for_loss_avg', 'college_assisted_tackle_avg',
               'college_int_avg', 'college_int_yds_avg', 'college_solo_tackles_avg']

# Prepare feature matrix and target vector
X_lb = lb_df[lb_features]
y_lb = lb_df['carav_per_year']

# Impute any missing values in the features
imputer = IterativeImputer(random_state=42)
X_lb_imputed = pd.DataFrame(imputer.fit_transform(X_lb), columns=lb_features)

# Transform target into categories: low, medium, high
y_bins = pd.qcut(y_lb, q=3, labels=[1, 2, 3])  # 1: low, 2: medium, 3: high
y_bins.fillna(1, inplace=True)  # Fill NaN values with the lowest bin

# Apply SMOTE to balance transformed target categories
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_lb_imputed, y_bins)

# Map categorical predictions back to continuous target values
y_resampled_continuous = y_resampled.map({
    1: y_lb[y_bins == 1].mean(),
    2: y_lb[y_bins == 2].mean(),
    3: y_lb[y_bins == 3].mean()
})

# Split data: train on 2008-2020, test on 2021-2023
train_data = lb_df[lb_df['player_year'] <= 2018]
test_data = lb_df[(lb_df['player_year'] >= 2019) & (lb_df['player_year'] <= 2023)]

X_lb_train, y_lb_train = train_data[lb_features], train_data['carav_per_year']
X_lb_test, y_lb_test = test_data[lb_features], test_data['carav_per_year']

# Train the XGBRegressor model on the resampled data
xgb_model = XGBRegressor(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.1,
    objective='reg:squarederror',
    random_state=42
)
xgb_model.fit(X_resampled, y_resampled_continuous)

# Make predictions on the 2021-2023 test set
y_lb_pred = xgb_model.predict(X_lb_test)

# Add predictions to the test data for analysis
test_data = test_data.copy()
test_data['predicted_carav_per_year'] = y_lb_pred

# Collect top 10 players each year for model and scouts
model_top_10_combined = []
scout_top_10_combined = []
common_top_10_combined = []

for year in [2019, 2020, 2021, 2022, 2023]:
    year_data = test_data[test_data['player_year'] == year]
    
    model_top_10 = year_data.sort_values(by='predicted_carav_per_year', ascending=False).head(10)
    scout_top_10 = year_data.sort_values(by='draft_pick').head(10)
    
    model_top_10 = model_top_10[['player_name', 'player_year', 'predicted_carav_per_year', 'carav_per_year']]
    scout_top_10 = scout_top_10[['player_name', 'player_year', 'carav_per_year']]
    
    common_top_10 = pd.merge(model_top_10, scout_top_10, on='player_name', suffixes=('_model', '_scout'))
    
    model_top_10_combined.append(model_top_10)
    scout_top_10_combined.append(scout_top_10)
    common_top_10_combined.append(common_top_10)

# Combine and calculate averages using actual carav_per_year values
model_top_10_all = pd.concat(model_top_10_combined)
scout_top_10_all = pd.concat(scout_top_10_combined)
common_top_10_all = pd.concat(common_top_10_combined)

model_avg_carav_per_year_all = model_top_10_all['carav_per_year'].mean()  # Using actual carav_per_year
scout_avg_carav_per_year_all = scout_top_10_all['carav_per_year'].mean()
common_avg_carav_per_year_all = common_top_10_all['carav_per_year_model'].mean()  # Using actual carav_per_year

# Display results and conduct t-test
print(f"\nMean carav_per_year for Model's Combined Top 10 Predicted Players per year (2019-2023): {model_avg_carav_per_year_all:.4f}")
print(f"Mean carav_per_year for Scouts' Combined Top 10 Selected Players per year (2019-2023): {scout_avg_carav_per_year_all:.4f}")
print(f"Mean carav_per_year for Common Top 10 Players in Both Model and Scout Selections per year (2019-2023): {common_avg_carav_per_year_all:.4f}")

scout_carav_values = scout_top_10_all['carav_per_year'].dropna()
common_carav_values = common_top_10_all['carav_per_year_model'].dropna()

t_stat, p_value = ttest_ind(scout_carav_values, common_carav_values, equal_var=False)
mean_diff = common_carav_values.mean() - scout_carav_values.mean()
pooled_std = np.sqrt((common_carav_values.var(ddof=1) / len(common_carav_values)) +
                     (scout_carav_values.var(ddof=1) / len(scout_carav_values)))
ci_lower = mean_diff - 1.96 * pooled_std
ci_upper = mean_diff + 1.96 * pooled_std

print(f"\nTwo-Sample T-Test for carav_per_year between Scouts' and Common Top Players:")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"\nMean Difference in carav_per_year: {mean_diff:.4f}")
print(f"95% Confidence Interval for the Difference: [{ci_lower:.4f}, {ci_upper:.4f}]")
if p_value < 0.05:
    print("The difference in carav_per_year between the scout top 10 and the common top 10 (model & scout) players is statistically significant (p < 0.05).")
else:
    print("There is no statistically significant difference in carav_per_year between the scout top 10 and the common top 10 (model & scout) players.")

    
scout_carav_values = scout_top_10_all['carav_per_year'].dropna()
model_carav_values = model_top_10_all['carav_per_year'].dropna()


t_stat, p_value = ttest_ind(scout_carav_values, model_carav_values, equal_var=False)
mean_diff = model_carav_values.mean() - scout_carav_values.mean()
pooled_std = np.sqrt((model_carav_values.var(ddof=1) / len(model_carav_values)) +
                     (scout_carav_values.var(ddof=1) / len(scout_carav_values)))
ci_lower = mean_diff - 1.96 * pooled_std
ci_upper = mean_diff + 1.96 * pooled_std


print(f"\nTwo-Sample T-Test for carav_per_year between Scouts' and Model Top Players:")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"\nMean Difference in carav_per_year: {mean_diff:.4f}")
print(f"95% Confidence Interval for the Difference: [{ci_lower:.4f}, {ci_upper:.4f}]")
if p_value < 0.05:
    print("The difference in carav_per_year between the scout top 10 and the model top 10 players is statistically significant (p < 0.05).")
else:
    print("There is no statistically significant difference in carav_per_year between the scout top 10 and the model players.")
     
    
    
# Display the combined top 30 model-predicted players for 2021-2023 with actual carav_per_year values
print("\nTop 10 Predicted Players by Model per year (2019-2023):")
print(model_top_10_all.sort_values(by=['player_year', 'carav_per_year'], ascending=[True, False]).to_string(index=False))

# Display the combined top 30 scout-selected players for 2021-2023 with actual carav_per_year values
print("\nTop 10 Players Selected by Scouts per year (2019-2023):")
print(scout_top_10_all.sort_values(by=['player_year', 'carav_per_year'], ascending=[True, False]).to_string(index=False))

# Display the combined common top 30 players between model and scouts for 2021-2023 with actual carav_per_year values
print("\nCombined Common Top 10 Players in Both Model and Scout Selections per year (2019-2023):")
print(common_top_10_all.sort_values(by=['player_year_model', 'carav_per_year_model'], ascending=[True, False]).to_string(index=False))

# Display means for each group for comparison
model_avg_carav_per_year_all = model_top_10_all['carav_per_year'].mean()
scout_avg_carav_per_year_all = scout_top_10_all['carav_per_year'].mean()
common_avg_carav_per_year_all = common_top_10_all['carav_per_year_model'].mean()

print(f"\nMean carav_per_year for Model's Top 10 Predicted Players per year (2019-2023): {model_avg_carav_per_year_all:.4f}")
print(f"Mean carav_per_year for Scouts'Top 10 Selected Players per year (2019-2023): {scout_avg_carav_per_year_all:.4f}")
print(f"Mean carav_per_year for Common Top 10 Players in Both Model and Scout Selections per year (2019-2023): {common_avg_carav_per_year_all:.4f}")

# Evaluate the model on the test set
mae = mean_absolute_error(y_lb_test, y_lb_pred)
rmse = np.sqrt(mean_squared_error(y_lb_test, y_lb_pred))
r2 = r2_score(y_lb_test, y_lb_pred)

# Print the regression performance metrics
print("\nRegression Performance Metrics for Test Set (2019-2023):")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (R2): {r2:.4f}")

joblib.dump(xgb_model, 'xgb_lb_model.pkl')
# Out:
# C:\Users\benfi\AppData\Local\Temp/ipykernel_72452/1597206628.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lb_df['carav_per_year'].fillna(0, inplace=True)
# Mean carav_per_year for Model's Combined Top 10 Predicted Players per year (2019-2023): 7.2967
# Mean carav_per_year for Scouts' Combined Top 10 Selected Players per year (2019-2023): 6.1167
# Mean carav_per_year for Common Top 10 Players in Both Model and Scout Selections per year (2019-2023): 8.2446
#
# Two-Sample T-Test for carav_per_year between Scouts' and Common Top Players:
# T-statistic: -2.0163
# P-value: 0.0479
#
# Mean Difference in carav_per_year: 2.1280
# 95% Confidence Interval for the Difference: [0.0594, 4.1965]
# The difference in carav_per_year between the scout top 10 and the common top 10 (model & scout) players is statistically significant (p < 0.05).
#
# Two-Sample T-Test for carav_per_year between Scouts' and Model Top Players:
# T-statistic: -1.2971
# P-value: 0.1977
#
# Mean Difference in carav_per_year: 1.1800
# 95% Confidence Interval for the Difference: [-0.6031, 2.9631]
# There is no statistically significant difference in carav_per_year between the scout top 10 and the model players.
#
# Top 10 Predicted Players by Model per year (2019-2023):
#             player_name  player_year  predicted_carav_per_year  carav_per_year
#             Devin White       2019.0                  7.055594       11.250000
#          Germaine Pratt       2019.0                  6.936987        8.500000
#              Josh Allen       2019.0                  6.689428        8.000000
#           Bobby Okereke       2019.0                  7.121686        7.250000
#           Jahlani Tavai       2019.0                  5.828164        6.250000
#          Devin Bush Jr.       2019.0                  7.049063        6.000000
#       Andrew Van Ginkel       2019.0                  6.323366        6.000000
#             Rashan Gary       2019.0                  6.938660        5.000000
#          Sione Takitaki       2019.0                  6.726717        4.750000
#          Drue Tranquill       2019.0                  7.153127        4.500000
#           Patrick Queen       2020.0                  7.159594       13.000000
#          Alex Highsmith       2020.0                  7.021308        8.666667
#            Logan Wilson       2020.0                  7.063658        8.333333
#           Jordyn Brooks       2020.0                  6.870800        7.666667
#          Willie Gay Jr.       2020.0                  7.086602        7.333333
#          Isaiah Simmons       2020.0                  5.768694        6.333333
#             Tae Crowder       2020.0                  5.178530        5.333333
#          Malik Harrison       2020.0                  6.543347        4.666667
#       Anfernee Jennings       2020.0                  5.531300        4.666667
#            Mykal Walker       2020.0                  6.753279        4.333333
#           Micah Parsons       2021.0                  7.108467       25.000000
#             Pete Werner       2021.0                  6.907536        9.000000
# Jeremiah Owusu-Koramoah       2021.0                  6.819345        9.000000
#      Joe Tryon-Shoyinka       2021.0                  6.820399        8.500000
#             Nick Bolton       2021.0                  7.222672        8.000000
#          Baron Browning       2021.0                  7.119773        7.000000
#           Zaven Collins       2021.0                  7.054659        7.000000
#           Azeez Ojulari       2021.0                  7.020350        7.000000
#            Ernest Jones       2021.0                  6.352182        7.000000
#             Tony Fields       2021.0                  7.095824        4.500000
#             Devin Lloyd       2022.0                  7.034825       15.000000
#             Quay Walker       2022.0                  6.347750       13.000000
#     Jermaine Johnson II       2022.0                  6.029627       13.000000
#          Terrel Bernard       2022.0                  4.645391       13.000000
#        Christian Harris       2022.0                  6.034583       12.000000
#          Micah McFadden       2022.0                  5.647655       12.000000
#            Damone Clark       2022.0                  5.828170       11.000000
#       Malcolm Rodriguez       2022.0                  5.042005        8.000000
#             Nik Bonitto       2022.0                  6.940353        5.000000
#          Baylon Spector       2022.0                  5.044400        2.000000
#           Will Anderson       2023.0                  6.291861       10.000000
#             Byron Young       2023.0                  4.448155        7.000000
#           Jack Campbell       2023.0                  7.098160        5.000000
#            Drew Sanders       2023.0                  4.407610        2.000000
#         Trenton Simpson       2023.0                  4.158261        2.000000
#         Dorian Williams       2023.0                  3.444738        2.000000
#           Daiyan Henley       2023.0                  5.085681        1.000000
#             Owen Pappoe       2023.0                  4.296346        1.000000
#            Amari Burney       2023.0                  3.483212        1.000000
#         Ventrell Miller       2023.0                  3.827736        0.000000
#
# Top 10 Players Selected by Scouts per year (2019-2023):
#             player_name  player_year  carav_per_year
#             Devin White       2019.0       11.250000
#          Germaine Pratt       2019.0        8.500000
#              Josh Allen       2019.0        8.000000
#           Jahlani Tavai       2019.0        6.250000
#          Devin Bush Jr.       2019.0        6.000000
#             Rashan Gary       2019.0        5.000000
#          Sione Takitaki       2019.0        4.750000
#             Cody Barton       2019.0        3.750000
#              Ben Banogu       2019.0        1.333333
#           Jachai Polite       2019.0        1.000000
#           Patrick Queen       2020.0       13.000000
#            Logan Wilson       2020.0        8.333333
#          Kenneth Murray       2020.0        7.666667
#           Jordyn Brooks       2020.0        7.666667
#          Willie Gay Jr.       2020.0        7.333333
#          Isaiah Simmons       2020.0        6.333333
#       Anfernee Jennings       2020.0        4.666667
#               Zack Baun       2020.0        3.333333
#               Josh Uche       2020.0        2.666667
#           Terrell Lewis       2020.0        2.500000
#           Micah Parsons       2021.0       25.000000
# Jeremiah Owusu-Koramoah       2021.0        9.000000
#             Pete Werner       2021.0        9.000000
#      Joe Tryon-Shoyinka       2021.0        8.500000
#             Jamin Davis       2021.0        8.000000
#             Nick Bolton       2021.0        8.000000
#           Zaven Collins       2021.0        7.000000
#           Azeez Ojulari       2021.0        7.000000
#            Joseph Ossai       2021.0        2.000000
#           Chazz Surratt       2021.0        1.000000
#             Devin Lloyd       2022.0       15.000000
#             Quay Walker       2022.0       13.000000
#     Jermaine Johnson II       2022.0       13.000000
#        Christian Harris       2022.0       12.000000
#             Nik Bonitto       2022.0        5.000000
#               Chad Muma       2022.0        4.000000
#           Drake Jackson       2022.0        3.000000
#           Brian Asamoah       2022.0        2.000000
#             Nakobe Dean       2022.0        2.000000
#             David Ojabo       2022.0        1.000000
#           Will Anderson       2023.0       10.000000
#             Byron Young       2023.0        7.000000
#           Jack Campbell       2023.0        5.000000
#            Tyree Wilson       2023.0        2.000000
#            Drew Sanders       2023.0        2.000000
#              DJ Johnson       2023.0        2.000000
#         Trenton Simpson       2023.0        2.000000
#             Nolan Smith       2023.0        1.000000
#           Daiyan Henley       2023.0        1.000000
#     DeMarvion Overshown       2023.0        0.000000
#
# Combined Common Top 10 Players in Both Model and Scout Selections per year (2019-2023):
#             player_name  player_year_model  predicted_carav_per_year  carav_per_year_model  player_year_scout  carav_per_year_scout
#             Devin White             2019.0                  7.055594             11.250000             2019.0             11.250000
#          Germaine Pratt             2019.0                  6.936987              8.500000             2019.0              8.500000
#              Josh Allen             2019.0                  6.689428              8.000000             2019.0              8.000000
#           Jahlani Tavai             2019.0                  5.828164              6.250000             2019.0              6.250000
#          Devin Bush Jr.             2019.0                  7.049063              6.000000             2019.0              6.000000
#             Rashan Gary             2019.0                  6.938660              5.000000             2019.0              5.000000
#          Sione Takitaki             2019.0                  6.726717              4.750000             2019.0              4.750000
#           Patrick Queen             2020.0                  7.159594             13.000000             2020.0             13.000000
#            Logan Wilson             2020.0                  7.063658              8.333333             2020.0              8.333333
#           Jordyn Brooks             2020.0                  6.870800              7.666667             2020.0              7.666667
#          Willie Gay Jr.             2020.0                  7.086602              7.333333             2020.0              7.333333
#          Isaiah Simmons             2020.0                  5.768694              6.333333             2020.0              6.333333
#       Anfernee Jennings             2020.0                  5.531300              4.666667             2020.0              4.666667
#           Micah Parsons             2021.0                  7.108467             25.000000             2021.0             25.000000
#             Pete Werner             2021.0                  6.907536              9.000000             2021.0              9.000000
# Jeremiah Owusu-Koramoah             2021.0                  6.819345              9.000000             2021.0              9.000000
#      Joe Tryon-Shoyinka             2021.0                  6.820399              8.500000             2021.0              8.500000
#             Nick Bolton             2021.0                  7.222672              8.000000             2021.0              8.000000
#           Zaven Collins             2021.0                  7.054659              7.000000             2021.0              7.000000
#           Azeez Ojulari             2021.0                  7.020350              7.000000             2021.0              7.000000
#             Devin Lloyd             2022.0                  7.034825             15.000000             2022.0             15.000000
#             Quay Walker             2022.0                  6.347750             13.000000             2022.0             13.000000
#     Jermaine Johnson II             2022.0                  6.029627             13.000000             2022.0             13.000000
#        Christian Harris             2022.0                  6.034583             12.000000             2022.0             12.000000
#             Nik Bonitto             2022.0                  6.940353              5.000000             2022.0              5.000000
#           Will Anderson             2023.0                  6.291861             10.000000             2023.0             10.000000
#             Byron Young             2023.0                  4.448155              7.000000             2023.0              7.000000
#           Jack Campbell             2023.0                  7.098160              5.000000             2023.0              5.000000
#            Drew Sanders             2023.0                  4.407610              2.000000             2023.0              2.000000
#         Trenton Simpson             2023.0                  4.158261              2.000000             2023.0              2.000000
#           Daiyan Henley             2023.0                  5.085681              1.000000             2023.0              1.000000
#
# Mean carav_per_year for Model's Top 10 Predicted Players per year (2019-2023): 7.2967
# Mean carav_per_year for Scouts'Top 10 Selected Players per year (2019-2023): 6.1167
# Mean carav_per_year for Common Top 10 Players in Both Model and Scout Selections per year (2019-2023): 8.2446
#
# Regression Performance Metrics for Test Set (2019-2023):
# Mean Absolute Error (MAE): 2.0089
# Root Mean Squared Error (RMSE): 2.9396
# R-squared (R2): 0.4530
# ['xgb_lb_model.pkl']

# %%
#without smote

# %%
# import pandas as pd
# import numpy as np
# from xgboost import XGBRegressor
# from sklearn.experimental import enable_iterative_imputer
# from sklearn.impute import IterativeImputer
# from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# import joblib

# # Fill NaN in `carav_per_year` with 0
# lb_df['carav_per_year'].fillna(0, inplace=True)

# # Define features and impute missing values for the LB position group
# lb_features = ['combine_shuttle', 'combine_broad', 'combine_vertical', 'combine_forty',
#                'college_total_tackles_avg', 'college_tackles_for_loss_avg', 'college_assisted_tackle_avg',
#                'college_int_avg', 'college_int_yds_avg', 'college_solo_tackles_avg']

# # Prepare feature matrix and target vector
# X_lb_no_smote = lb_df[lb_features]
# y_lb_no_smote = lb_df['carav_per_year']

# # Impute any missing values in the features
# imputer = IterativeImputer(random_state=42)
# X_lb_no_smote_imputed = pd.DataFrame(imputer.fit_transform(X_lb_no_smote), columns=lb_features)

# # Split data: train on 2008-2020, test on 2021-2023
# train_data_no_smote = lb_df[lb_df['player_year'] <= 2018]
# test_data_no_smote = lb_df[(lb_df['player_year'] >= 2019) & (lb_df['player_year'] <= 2023)]

# X_lb_train_no_smote, y_lb_train_no_smote = train_data_no_smote[lb_features], train_data_no_smote['carav_per_year']
# X_lb_test_no_smote, y_lb_test_no_smote = test_data_no_smote[lb_features], test_data_no_smote['carav_per_year']

# # Train the XGBRegressor model without SMOTE
# xgb_model_no_smote = XGBRegressor(
#     n_estimators=200,
#     max_depth=6,
#     learning_rate=0.1,
#     objective='reg:squarederror',
#     random_state=42
# )
# xgb_model_no_smote.fit(X_lb_train_no_smote, y_lb_train_no_smote)

# # Make predictions on the 2021-2023 test set
# y_lb_pred_no_smote = xgb_model_no_smote.predict(X_lb_test_no_smote)

# # Add predictions to the test data for analysis
# test_data_no_smote = test_data_no_smote.copy()
# test_data_no_smote['predicted_carav_per_year'] = y_lb_pred_no_smote

# # Evaluate the model on the test set
# mae_no_smote = mean_absolute_error(y_lb_test_no_smote, y_lb_pred_no_smote)
# rmse_no_smote = np.sqrt(mean_squared_error(y_lb_test_no_smote, y_lb_pred_no_smote))
# r2_no_smote = r2_score(y_lb_test_no_smote, y_lb_pred_no_smote)

# # Print the regression performance metrics
# print("\nRegression Performance Metrics for Test Set (2019-2023) Without SMOTE:")
# print(f"Mean Absolute Error (MAE): {mae_no_smote:.4f}")
# print(f"Root Mean Squared Error (RMSE): {rmse_no_smote:.4f}")
# print(f"R-squared (R2): {r2_no_smote:.4f}")

# %%
#randomforest

# %%
# import pandas as pd
# import numpy as np
# from sklearn.experimental import enable_iterative_imputer
# from sklearn.impute import IterativeImputer
# from imblearn.over_sampling import SMOTE
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# from scipy.stats import ttest_ind
# import joblib

# # Fill NaN in `carav_per_year` with 0
# lb_df['carav_per_year'].fillna(0, inplace=True)

# # Define features and impute missing values for the LB position group
# lb_features = ['combine_shuttle', 'combine_broad', 'combine_vertical', 'combine_forty',
#                'college_total_tackles_avg', 'college_tackles_for_loss_avg', 'college_assisted_tackle_avg',
#                'college_int_avg', 'college_int_yds_avg', 'college_solo_tackles_avg']

# # Prepare feature matrix and target vector
# X_lb = lb_df[lb_features]
# y_lb = lb_df['carav_per_year']

# # Impute any missing values in the features
# imputer = IterativeImputer(random_state=42)
# X_lb_imputed = pd.DataFrame(imputer.fit_transform(X_lb), columns=lb_features)

# # Transform target into categories: low, medium, high
# y_bins = pd.qcut(y_lb, q=3, labels=[1, 2, 3])  # 1: low, 2: medium, 3: high
# y_bins.fillna(1, inplace=True)  # Fill NaN values with the lowest bin

# # Apply SMOTE to balance transformed target categories
# smote = SMOTE(random_state=42)
# X_resampled, y_resampled = smote.fit_resample(X_lb_imputed, y_bins)

# # Map categorical predictions back to continuous target values
# y_resampled_continuous = y_resampled.map({
#     1: y_lb[y_bins == 1].mean(),
#     2: y_lb[y_bins == 2].mean(),
#     3: y_lb[y_bins == 3].mean()
# })

# # Split data: train on 2008-2020, test on 2021-2023
# train_data = lb_df[lb_df['player_year'] <= 2018]
# test_data = lb_df[(lb_df['player_year'] >= 2019) & (lb_df['player_year'] <= 2023)]

# X_lb_train, y_lb_train = train_data[lb_features], train_data['carav_per_year']
# X_lb_test, y_lb_test = test_data[lb_features], test_data['carav_per_year']

# # Train the RandomForestRegressor model on the resampled data
# rf_model = RandomForestRegressor(
#     n_estimators=200,
#     max_depth=10,
#     random_state=42
# )
# rf_model.fit(X_resampled, y_resampled_continuous)

# # Make predictions on the 2021-2023 test set
# y_lb_pred = rf_model.predict(X_lb_test)

# # Add predictions to the test data for analysis
# test_data = test_data.copy()
# test_data['predicted_carav_per_year'] = y_lb_pred

# # Collect top 10 players each year for model and scouts
# model_top_10_combined = []
# scout_top_10_combined = []
# common_top_10_combined = []

# for year in [2019, 2020, 2021, 2022, 2023]:
#     year_data = test_data[test_data['player_year'] == year]
    
#     model_top_10 = year_data.sort_values(by='predicted_carav_per_year', ascending=False).head(10)
#     scout_top_10 = year_data.sort_values(by='draft_pick').head(10)
    
#     model_top_10 = model_top_10[['player_name', 'player_year', 'predicted_carav_per_year', 'carav_per_year']]
#     scout_top_10 = scout_top_10[['player_name', 'player_year', 'carav_per_year']]
    
#     common_top_10 = pd.merge(model_top_10, scout_top_10, on='player_name', suffixes=('_model', '_scout'))
    
#     model_top_10_combined.append(model_top_10)
#     scout_top_10_combined.append(scout_top_10)
#     common_top_10_combined.append(common_top_10)

# # Combine and calculate averages using actual carav_per_year values
# model_top_10_all = pd.concat(model_top_10_combined)
# scout_top_10_all = pd.concat(scout_top_10_combined)
# common_top_10_all = pd.concat(common_top_10_combined)

# model_avg_carav_per_year_all = model_top_10_all['carav_per_year'].mean()  # Using actual carav_per_year
# scout_avg_carav_per_year_all = scout_top_10_all['carav_per_year'].mean()
# common_avg_carav_per_year_all = common_top_10_all['carav_per_year_model'].mean()  # Using actual carav_per_year

# # Display results and conduct t-test
# print(f"\nMean carav_per_year for Model's Combined Top 10 Predicted Players per year (2019-2023): {model_avg_carav_per_year_all:.4f}")
# print(f"Mean carav_per_year for Scouts' Combined Top 10 Selected Players per year (2019-2023): {scout_avg_carav_per_year_all:.4f}")
# print(f"Mean carav_per_year for Common Top 10 Players in Both Model and Scout Selections per year (2019-2023): {common_avg_carav_per_year_all:.4f}")

# scout_carav_values = scout_top_10_all['carav_per_year'].dropna()
# common_carav_values = common_top_10_all['carav_per_year_model'].dropna()

# t_stat, p_value = ttest_ind(scout_carav_values, common_carav_values, equal_var=False)
# mean_diff = common_carav_values.mean() - scout_carav_values.mean()
# pooled_std = np.sqrt((common_carav_values.var(ddof=1) / len(common_carav_values)) +
#                      (scout_carav_values.var(ddof=1) / len(scout_carav_values)))
# ci_lower = mean_diff - 1.96 * pooled_std
# ci_upper = mean_diff + 1.96 * pooled_std

# print(f"\nTwo-Sample T-Test for carav_per_year between Scouts' and Common Top Players:")
# print(f"T-statistic: {t_stat:.4f}")
# print(f"P-value: {p_value:.4f}")
# print(f"\nMean Difference in carav_per_year: {mean_diff:.4f}")
# print(f"95% Confidence Interval for the Difference: [{ci_lower:.4f}, {ci_upper:.4f}]")
# if p_value < 0.05:
#     print("The difference in carav_per_year between the scout top 10 and the common top 10 (model & scout) players is statistically significant (p < 0.05).")
# else:
#     print("There is no statistically significant difference in carav_per_year between the scout top 10 and the common top 10 (model & scout) players.")

# # Evaluate the model on the test set
# mae = mean_absolute_error(y_lb_test, y_lb_pred)
# rmse = np.sqrt(mean_squared_error(y_lb_test, y_lb_pred))
# r2 = r2_score(y_lb_test, y_lb_pred)

# # Print the regression performance metrics
# print("\nRegression Performance Metrics for Test Set (2019-2023):")
# print(f"Mean Absolute Error (MAE): {mae:.4f}")
# print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
# print(f"R-squared (R2): {r2:.4f}")

# %%
import matplotlib.pyplot as plt

# Create line chart data for LB
years = [2019, 2020, 2021, 2022, 2023]

model_means = [model_top_10_combined[i]['carav_per_year'].mean() for i in range(len(years))]
scout_means = [scout_top_10_combined[i]['carav_per_year'].mean() for i in range(len(years))]
common_means = [common_top_10_combined[i]['carav_per_year_model'].mean() for i in range(len(years))]

# Plot the line chart
plt.figure(figsize=(10, 6))
plt.plot(years, model_means, marker='o', label="Model's Top 10")
plt.plot(years, scout_means, marker='o', label="Scouts' Top 10")
plt.plot(years, common_means, marker='o', label="Hybrid Top 10 (Model & Scouts)")

# Add labels, title, and legend
plt.xlabel("Year")
plt.ylabel("Mean CarAV per Year for LB")
plt.title("Mean CarAV per Year (2019-2023): Model, Scouts, and Hybrid Top 10 for LB")
plt.legend()
plt.grid()

# Set x-axis ticks to integers only
plt.xticks(years)

# Save the plot to the "pic" folder
output_path = "pic/line_chart_carav_per_year_comparison_lb.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight')

plt.show()
print(f"Line chart saved to {output_path}")
# Out:
# Line chart saved to pic/line_chart_carav_per_year_comparison_lb.png

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Prepare data for the box plot for LB
boxplot_data_lb = {
    "Group": ["Model's Top 10"] * len(model_top_10_all['carav_per_year']) +
             ["Scouts' Top 10"] * len(scout_top_10_all['carav_per_year']) +
             ["Hybrid Top 10 (Model & Scouts)"] * len(common_top_10_all['carav_per_year_model']),
    "CarAV per Year": pd.concat([model_top_10_all['carav_per_year'],
                                  scout_top_10_all['carav_per_year'],
                                  common_top_10_all['carav_per_year_model']])
}

boxplot_df_lb = pd.DataFrame(boxplot_data_lb)

# Create the box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x="Group", y="CarAV per Year", data=boxplot_df_lb, palette="Set2")

# Add title and labels
plt.title("Distribution of CarAV per Year by Group (2019-2023) for LB", fontsize=14)
plt.xlabel("Group", fontsize=12)
plt.ylabel("CarAV per Year", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Save the plot to the "pic" folder
output_path = "pic/boxplot_carav_per_year_by_group_lb.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight')

plt.show()
print(f"Box plot saved to {output_path}")
# Out:
# C:\Users\benfi\AppData\Local\Temp/ipykernel_72452/699296685.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Group", y="CarAV per Year", data=boxplot_df_lb, palette="Set2")
# Box plot saved to pic/boxplot_carav_per_year_by_group_lb.png

# %%
common_top_10_all = common_top_10_all.rename(columns={
    'player_year_model': 'player_year',
    'carav_per_year_model': 'carav_per_year'
})

# %%
# Saving the Model's Top 10 Predicted Players per year (2019-2023) for LB
model_top_10_all.to_csv('model_top_10_lb_2019_2023.csv', index=False)

# Saving the Scouts' Top 10 Selected Players per year (2019-2023) for LB
scout_top_10_all.to_csv('scout_top_10_lb_2019_2023.csv', index=False)

# Saving the Combined Common Top 10 Players in Both Model and Scout Selections per year (2019-2023) for LB
common_top_10_all.to_csv('common_top_10_lb_2019_2023.csv', index=False)

# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from imblearn.over_sampling import SMOTE
from scipy.stats import ttest_ind
import joblib

# Fill NaN in `carav_per_year` with 0
lb_df['carav_per_year'].fillna(0, inplace=True)

# Define features and impute missing values for the LB position group
lb_features = ['combine_shuttle', 'combine_broad', 'combine_vertical', 'combine_forty',
               'college_total_tackles_avg', 'college_tackles_for_loss_avg', 'college_assisted_tackle_avg',
               'college_int_avg', 'college_int_yds_avg', 'college_solo_tackles_avg']

# Prepare feature matrix and target vector
X_lb = lb_df[lb_features]
y_lb = lb_df['carav_per_year']

# Impute any missing values in the features
imputer = IterativeImputer(random_state=42)
X_lb_imputed = pd.DataFrame(imputer.fit_transform(X_lb), columns=lb_features)

# Transform target into categories: low, medium, high
y_bins = pd.qcut(y_lb, q=3, labels=[1, 2, 3])  # 1: low, 2: medium, 3: high
y_bins.fillna(1, inplace=True)  # Fill NaN values with the lowest bin

# Apply SMOTE to balance transformed target categories
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_lb_imputed, y_bins)

# Map categorical predictions back to continuous target values
y_resampled_continuous = y_resampled.map({
    1: y_lb[y_bins == 1].mean(),
    2: y_lb[y_bins == 2].mean(),
    3: y_lb[y_bins == 3].mean()
})

# Split data: train on 2013-2023, test on 2008-2012
train_data = lb_df[lb_df['player_year'] >= 2013]
test_data = lb_df[(lb_df['player_year'] >= 2008) & (lb_df['player_year'] <= 2012)]

X_lb_train, y_lb_train = train_data[lb_features], train_data['carav_per_year']
X_lb_test, y_lb_test = test_data[lb_features], test_data['carav_per_year']

# Train the XGBRegressor model on the resampled data
xgb_model = XGBRegressor(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.1,
    objective='reg:squarederror',
    random_state=42
)
xgb_model.fit(X_resampled, y_resampled_continuous)

# Make predictions on the 2008-2012 test set
y_lb_pred = xgb_model.predict(X_lb_test)

# Add predictions to the test data for analysis
test_data = test_data.copy()
test_data['predicted_carav_per_year'] = y_lb_pred

# Collect top 10 players each year for model and scouts
model_top_10_combined = []
scout_top_10_combined = []
common_top_10_combined = []

for year in [2008, 2009, 2010, 2011, 2012]:
    year_data = test_data[test_data['player_year'] == year]
    
    model_top_10 = year_data.sort_values(by='predicted_carav_per_year', ascending=False).head(10)
    scout_top_10 = year_data.sort_values(by='draft_pick').head(10)
    
    model_top_10 = model_top_10[['player_name', 'player_year', 'predicted_carav_per_year', 'carav_per_year']]
    scout_top_10 = scout_top_10[['player_name', 'player_year', 'carav_per_year']]
    
    common_top_10 = pd.merge(model_top_10, scout_top_10, on='player_name', suffixes=('_model', '_scout'))
    
    model_top_10_combined.append(model_top_10)
    scout_top_10_combined.append(scout_top_10)
    common_top_10_combined.append(common_top_10)

# Combine and calculate averages using actual carav_per_year values
model_top_10_all = pd.concat(model_top_10_combined)
scout_top_10_all = pd.concat(scout_top_10_combined)
common_top_10_all = pd.concat(common_top_10_combined)

model_avg_carav_per_year_all = model_top_10_all['carav_per_year'].mean()  # Using actual carav_per_year
scout_avg_carav_per_year_all = scout_top_10_all['carav_per_year'].mean()
common_avg_carav_per_year_all = common_top_10_all['carav_per_year_model'].mean()  # Using actual carav_per_year

# Display results and conduct t-test
print(f"\nMean carav_per_year for Model's Combined Top 10 Predicted Players per year (2008-2012): {model_avg_carav_per_year_all:.4f}")
print(f"Mean carav_per_year for Scouts' Combined Top 10 Selected Players per year (2008-2012): {scout_avg_carav_per_year_all:.4f}")
print(f"Mean carav_per_year for Common Top 10 Players in Both Model and Scout Selections per year (2008-2012): {common_avg_carav_per_year_all:.4f}")

scout_carav_values = scout_top_10_all['carav_per_year'].dropna()
common_carav_values = common_top_10_all['carav_per_year_model'].dropna()

t_stat, p_value = ttest_ind(scout_carav_values, common_carav_values, equal_var=False)
mean_diff = common_carav_values.mean() - scout_carav_values.mean()
pooled_std = np.sqrt((common_carav_values.var(ddof=1) / len(common_carav_values)) +
                     (scout_carav_values.var(ddof=1) / len(scout_carav_values)))
ci_lower = mean_diff - 1.96 * pooled_std
ci_upper = mean_diff + 1.96 * pooled_std

print(f"\nTwo-Sample T-Test for carav_per_year between Scouts' and Common Top Players:")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"\nMean Difference in carav_per_year: {mean_diff:.4f}")
print(f"95% Confidence Interval for the Difference: [{ci_lower:.4f}, {ci_upper:.4f}]")
if p_value < 0.05:
    print("The difference in carav_per_year between the scout top 10 and the common top 10 (model & scout) players is statistically significant (p < 0.05).")
else:
    print("There is no statistically significant difference in carav_per_year between the scout top 10 and the common top 10 (model & scout) players.")

    
    
scout_carav_values = scout_top_10_all['carav_per_year'].dropna()
model_carav_values = model_top_10_all['carav_per_year'].dropna()


t_stat, p_value = ttest_ind(scout_carav_values, model_carav_values, equal_var=False)
mean_diff = model_carav_values.mean() - scout_carav_values.mean()
pooled_std = np.sqrt((model_carav_values.var(ddof=1) / len(model_carav_values)) +
                     (scout_carav_values.var(ddof=1) / len(scout_carav_values)))
ci_lower = mean_diff - 1.96 * pooled_std
ci_upper = mean_diff + 1.96 * pooled_std


print(f"\nTwo-Sample T-Test for carav_per_year between Scouts' and Model Top Players:")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"\nMean Difference in carav_per_year: {mean_diff:.4f}")
print(f"95% Confidence Interval for the Difference: [{ci_lower:.4f}, {ci_upper:.4f}]")
if p_value < 0.05:
    print("The difference in carav_per_year between the scout top 10 and the model top 10 players is statistically significant (p < 0.05).")
else:
    print("There is no statistically significant difference in carav_per_year between the scout top 10 and the model players.")
     
    
# Display the combined top 30 model-predicted players for 2008-2012 with actual carav_per_year values
print("\nTop 10 Predicted Players by Model per year (2008-2012):")
print(model_top_10_all.sort_values(by=['player_year', 'carav_per_year'], ascending=[True, False]).to_string(index=False))

# Display the combined top 30 scout-selected players for 2008-2012 with actual carav_per_year values
print("\nTop 10 Players Selected by Scouts per year (2008-2012):")
print(scout_top_10_all.sort_values(by=['player_year', 'carav_per_year'], ascending=[True, False]).to_string(index=False))

# Display the combined common top 30 players between model and scouts for 2008-2012 with actual carav_per_year values
print("\nCombined Common Top 10 Players in Both Model and Scout Selections per year (2008-2012):")
print(common_top_10_all.sort_values(by=['player_year_model', 'carav_per_year_model'], ascending=[True, False]).to_string(index=False))

# Display means for each group for comparison
model_avg_carav_per_year_all = model_top_10_all['carav_per_year'].mean()
scout_avg_carav_per_year_all = scout_top_10_all['carav_per_year'].mean()
common_avg_carav_per_year_all = common_top_10_all['carav_per_year_model'].mean()

print(f"\nMean carav_per_year for Model's Top 10 Predicted Players per year (2008-2012): {model_avg_carav_per_year_all:.4f}")
print(f"Mean carav_per_year for Scouts' Top 10 Selected Players per year (2008-2012): {scout_avg_carav_per_year_all:.4f}")
print(f"Mean carav_per_year for Common Top 10 Players in Both Model and Scout Selections per year (2008-2012): {common_avg_carav_per_year_all:.4f}")
# Out:
# C:\Users\benfi\AppData\Local\Temp/ipykernel_72452/3061060337.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lb_df['carav_per_year'].fillna(0, inplace=True)
# Mean carav_per_year for Model's Combined Top 10 Predicted Players per year (2008-2012): 5.2914
# Mean carav_per_year for Scouts' Combined Top 10 Selected Players per year (2008-2012): 4.9022
# Mean carav_per_year for Common Top 10 Players in Both Model and Scout Selections per year (2008-2012): 6.3456
#
# Two-Sample T-Test for carav_per_year between Scouts' and Common Top Players:
# T-statistic: -2.2652
# P-value: 0.0266
#
# Mean Difference in carav_per_year: 1.4434
# 95% Confidence Interval for the Difference: [0.1945, 2.6924]
# The difference in carav_per_year between the scout top 10 and the common top 10 (model & scout) players is statistically significant (p < 0.05).
#
# Two-Sample T-Test for carav_per_year between Scouts' and Model Top Players:
# T-statistic: -0.6709
# P-value: 0.5039
#
# Mean Difference in carav_per_year: 0.3892
# 95% Confidence Interval for the Difference: [-0.7478, 1.5263]
# There is no statistically significant difference in carav_per_year between the scout top 10 and the model players.
#
# Top 10 Predicted Players by Model per year (2008-2012):
#         player_name  player_year  predicted_carav_per_year  carav_per_year
#          Jerod Mayo       2008.0                  7.013895        7.285714
#       Curtis Lofton       2008.0                  7.007679        7.000000
#         Cliff Avril       2008.0                  7.091209        5.666667
#          Geno Hayes       2008.0                  7.028461        5.000000
#       Jonathan Goff       2008.0                  7.037551        4.500000
#          Dan Connor       2008.0                  4.930772        2.600000
#       Joey LaRocque       2008.0                  4.185791        1.000000
#        Robert James       2008.0                  4.400555        0.200000
#           Beau Bell       2008.0                  4.093838        0.000000
#             Bo Ruud       2008.0                  4.051052        0.000000
#       Clay Matthews       2009.0                  7.057910        7.700000
#   James Laurinaitis       2009.0                  6.945932        7.285714
#       Brian Cushing       2009.0                  6.935760        6.500000
#        Brian Orakpo       2009.0                  4.011512        6.444444
#        DeAndre Levy       2009.0                  5.992945        6.428571
#        Rey Maualuga       2009.0                  4.134988        6.125000
#         Aaron Curry       2009.0                  7.073511        5.333333
#          Nic Harris       2009.0                  7.020091        5.000000
#       Kevin Ellison       2009.0                  4.104459        4.000000
#          Brad Jones       2009.0                  4.509303        3.000000
#    Daryl Washington       2010.0                  7.580513       11.333333
#      NaVorro Bowman       2010.0                  7.003401       10.142857
#         Pat Angerer       2010.0                  7.073924        6.000000
#            Sean Lee       2010.0                  4.346055        5.300000
#         Perry Riley       2010.0                  7.052197        5.000000
#            Koa Misi       2010.0                  6.992515        5.000000
#     Rolando McClain       2010.0                  6.635779        5.000000
# Jermaine Cunningham       2010.0                  5.045132        2.666667
# Stevenson Sylvester       2010.0                  4.644775        2.000000
#       Rennie Curran       2010.0                  4.405270        1.000000
#          Von Miller       2011.0                  7.010767        8.666667
#         K.J. Wright       2011.0                  6.854401        6.400000
#      Justin Houston       2011.0                  7.086102        6.166667
#         Brian Rolle       2011.0                  7.047857        6.000000
#        Mason Foster       2011.0                  6.984640        5.714286
#      Colin McCarthy       2011.0                  6.957002        5.500000
#         Akeem Ayers       2011.0                  7.065646        4.666667
#   Jacquian Williams       2011.0                  4.112896        4.333333
#         Nate Irving       2011.0                  4.438128        2.250000
#      Andrew Gachkar       2011.0                  4.151850        1.500000
#        Luke Kuechly       2012.0                  7.098223       13.000000
#       Demario Davis       2012.0                  6.931618        8.909091
#       Lavonte David       2012.0                  7.139340        7.818182
#    Dont'a Hightower       2012.0                  6.726468        7.222222
#      Olivier Vernon       2012.0                  6.955817        6.250000
#          Zach Brown       2012.0                  7.737295        5.857143
#       Nigel Bradham       2012.0                  6.916435        5.500000
#    Brandon Marshall       2012.0                  6.904625        5.000000
#    Mychal Kendricks       2012.0                  7.034640        4.750000
#     Tahir Whitehead       2012.0                  6.925597        4.555556
#
# Top 10 Players Selected by Scouts per year (2008-2012):
#         player_name  player_year  carav_per_year
#          Jerod Mayo       2008.0        7.285714
#       Curtis Lofton       2008.0        7.000000
#         Cliff Avril       2008.0        5.666667
#        Keith Rivers       2008.0        4.000000
#      Philip Wheeler       2008.0        3.625000
#          Dan Connor       2008.0        2.600000
#        Jordon Dizon       2008.0        2.000000
#      Tavares Gooden       2008.0        1.800000
#        Shawn Crable       2008.0        0.000000
#         Bruce Davis       2008.0        0.000000
#       Clay Matthews       2009.0        7.700000
#   James Laurinaitis       2009.0        7.285714
#       Brian Cushing       2009.0        6.500000
#        Brian Orakpo       2009.0        6.444444
#        DeAndre Levy       2009.0        6.428571
#        Rey Maualuga       2009.0        6.125000
#         Aaron Curry       2009.0        5.333333
#        Clint Sintim       2009.0        2.000000
#       Larry English       2009.0        1.400000
#       David Veikune       2009.0        1.000000
#    Daryl Washington       2010.0       11.333333
#      NaVorro Bowman       2010.0       10.142857
#         Pat Angerer       2010.0        6.000000
#            Sean Lee       2010.0        5.300000
#     Rolando McClain       2010.0        5.000000
#            Koa Misi       2010.0        5.000000
#      Brandon Spikes       2010.0        4.166667
#   Sean Weatherspoon       2010.0        3.142857
# Jermaine Cunningham       2010.0        2.666667
#       Rennie Curran       2010.0        1.000000
#          Von Miller       2011.0        8.666667
#      Justin Houston       2011.0        6.166667
#         Akeem Ayers       2011.0        4.666667
#         Brooks Reed       2011.0        4.111111
#     Kelvin Sheppard       2011.0        3.571429
#        Bruce Carter       2011.0        2.857143
#         Nate Irving       2011.0        2.250000
#       Martez Wilson       2011.0        1.000000
#        Jonas Mouton       2011.0        0.000000
#         Dontay Moch       2011.0        0.000000
#        Luke Kuechly       2012.0       13.000000
#        Bobby Wagner       2012.0       11.000000
#       Demario Davis       2012.0        8.909091
#       Lavonte David       2012.0        7.818182
#    Dont'a Hightower       2012.0        7.222222
#      Olivier Vernon       2012.0        6.250000
#          Zach Brown       2012.0        5.857143
#     Courtney Upshaw       2012.0        5.400000
#    Mychal Kendricks       2012.0        4.750000
#        Andre Branch       2012.0        3.666667
#
# Combined Common Top 10 Players in Both Model and Scout Selections per year (2008-2012):
#         player_name  player_year_model  predicted_carav_per_year  carav_per_year_model  player_year_scout  carav_per_year_scout
#          Jerod Mayo             2008.0                  7.013895              7.285714             2008.0              7.285714
#       Curtis Lofton             2008.0                  7.007679              7.000000             2008.0              7.000000
#         Cliff Avril             2008.0                  7.091209              5.666667             2008.0              5.666667
#          Dan Connor             2008.0                  4.930772              2.600000             2008.0              2.600000
#       Clay Matthews             2009.0                  7.057910              7.700000             2009.0              7.700000
#   James Laurinaitis             2009.0                  6.945932              7.285714             2009.0              7.285714
#       Brian Cushing             2009.0                  6.935760              6.500000             2009.0              6.500000
#        Brian Orakpo             2009.0                  4.011512              6.444444             2009.0              6.444444
#        DeAndre Levy             2009.0                  5.992945              6.428571             2009.0              6.428571
#        Rey Maualuga             2009.0                  4.134988              6.125000             2009.0              6.125000
#         Aaron Curry             2009.0                  7.073511              5.333333             2009.0              5.333333
#    Daryl Washington             2010.0                  7.580513             11.333333             2010.0             11.333333
#      NaVorro Bowman             2010.0                  7.003401             10.142857             2010.0             10.142857
#         Pat Angerer             2010.0                  7.073924              6.000000             2010.0              6.000000
#            Sean Lee             2010.0                  4.346055              5.300000             2010.0              5.300000
#            Koa Misi             2010.0                  6.992515              5.000000             2010.0              5.000000
#     Rolando McClain             2010.0                  6.635779              5.000000             2010.0              5.000000
# Jermaine Cunningham             2010.0                  5.045132              2.666667             2010.0              2.666667
#       Rennie Curran             2010.0                  4.405270              1.000000             2010.0              1.000000
#          Von Miller             2011.0                  7.010767              8.666667             2011.0              8.666667
#      Justin Houston             2011.0                  7.086102              6.166667             2011.0              6.166667
#         Akeem Ayers             2011.0                  7.065646              4.666667             2011.0              4.666667
#         Nate Irving             2011.0                  4.438128              2.250000             2011.0              2.250000
#        Luke Kuechly             2012.0                  7.098223             13.000000             2012.0             13.000000
#       Demario Davis             2012.0                  6.931618              8.909091             2012.0              8.909091
#       Lavonte David             2012.0                  7.139340              7.818182             2012.0              7.818182
#    Dont'a Hightower             2012.0                  6.726468              7.222222             2012.0              7.222222
#      Olivier Vernon             2012.0                  6.955817              6.250000             2012.0              6.250000
#          Zach Brown             2012.0                  7.737295              5.857143             2012.0              5.857143
#    Mychal Kendricks             2012.0                  7.034640              4.750000             2012.0              4.750000
#
# Mean carav_per_year for Model's Top 10 Predicted Players per year (2008-2012): 5.2914
# Mean carav_per_year for Scouts' Top 10 Selected Players per year (2008-2012): 4.9022
# Mean carav_per_year for Common Top 10 Players in Both Model and Scout Selections per year (2008-2012): 6.3456

# %%
#2024 models

# %%
# Filter out data for 2024 only for each position group
dl_2024_df = complete_drafted_df[(complete_drafted_df['position_group'] == 'DL') & (complete_drafted_df['player_year'] == 2024)]
lb_2024_df = complete_drafted_df[(complete_drafted_df['position_group'] == 'LB') & (complete_drafted_df['player_year'] == 2024)]
db_2024_df = complete_drafted_df[(complete_drafted_df['position_group'] == 'DB') & (complete_drafted_df['player_year'] == 2024)]

# Display the first few rows of each to verify data
print("DL 2024 Data")
print(dl_2024_df.head())
print("\nLB 2024 Data")
print(lb_2024_df.head())
print("\nDB 2024 Data")
print(db_2024_df.head())
# Out:
# DL 2024 Data
#                                                     URL            School  \
# 1847  https://www.sports-reference.com/cfb/players/a...        Penn State
# 1849  https://www.sports-reference.com/cfb/players/a...            Kansas
# 1850  https://www.sports-reference.com/cfb/players/b...  Western Michigan
# 1851  https://www.sports-reference.com/cfb/players/b...        Washington
# 1852  https://www.sports-reference.com/cfb/players/b...            Oregon
#
#          Conf     G  college_solo_tackles  college_assisted_tackle  \
# 1847  Big Ten  46.0                  47.0                     45.0
# 1849   Big 12  18.0                  41.0                     17.0
# 1850      MAC  58.0                  92.0                    100.0
# 1851   Pac-12  40.0                  63.0                     38.0
# 1852   Pac-12  58.0                  58.0                     50.0
#
#       college_total_tackles  college_tackles_for_loss  college_sk  \
# 1847                   92.0                      32.0        14.5
# 1849                   58.0                      13.0         8.0
# 1850                  192.0                      37.0        19.0
# 1851                  101.0                      29.0        18.0
# 1852                  108.0                      28.0        12.0
#
#       college_int  ...  college_int_yds_avg  college_int_td_avg  \
# 1847          0.0  ...                  0.0            0.000000
# 1849          0.0  ...                  0.0            0.055556
# 1850          0.0  ...                  0.0            0.051724
# 1851          0.0  ...                  0.0            0.050000
# 1852          0.0  ...                  0.0            0.241379
#
#       college_passes_defended_avg  college_fumbles_recov_avg  \
# 1847                     0.021739                        0.0
# 1849                     0.000000                        0.0
# 1850                     0.034483                        0.0
# 1851                     0.050000                        0.0
# 1852                     0.017241                        0.0
#
#       college_fumbles_recov_yds_avg  college_fumbles_recov_td_avg  \
# 1847                          0.000                      0.043478
# 1849                          0.000                      0.111111
# 1850                          0.000                      0.051724
# 1851                          0.025                      0.025000
# 1852                          0.000                      0.000000
#
#       college_fumbles_forced_avg  drafted  position_group  power_5
# 1847                         0.0     True              DL     True
# 1849                         0.0     True              DL     True
# 1850                         0.0     True              DL    False
# 1851                         0.0     True              DL     True
# 1852                         0.0     True              DL     True
#
# [5 rows x 72 columns]
#
# LB 2024 Data
#                                                     URL          School  \
# 1858  https://www.sports-reference.com/cfb/players/c...  North Carolina
# 1861  https://www.sports-reference.com/cfb/players/c...         Alabama
# 1867  https://www.sports-reference.com/cfb/players/d...         Alabama
# 1868  https://www.sports-reference.com/cfb/players/d...          Hawaii
# 1876  https://www.sports-reference.com/cfb/players/e...      Washington
#
#         Conf     G  college_solo_tackles  college_assisted_tackle  \
# 1858     ACC  50.0                 199.0                    170.0
# 1861     SEC  41.0                  31.0                     44.0
# 1867     SEC  42.0                  58.0                     62.0
# 1868     MWC  63.0                 261.0                    179.0
# 1876  Pac-12  46.0                 153.0                     98.0
#
#       college_total_tackles  college_tackles_for_loss  college_sk  \
# 1858                  369.0                      30.0         8.5
# 1861                   75.0                      16.0        10.5
# 1867                  120.0                      33.0        22.5
# 1868                  440.0                      41.0        16.5
# 1876                  251.0                      16.0         7.0
#
#       college_int  ...  college_int_yds_avg  college_int_td_avg  \
# 1858          5.0  ...             1.020000            0.000000
# 1861          1.0  ...             0.682927            0.024390
# 1867          0.0  ...             0.000000            0.023810
# 1868          5.0  ...             1.285714            0.015873
# 1876          1.0  ...             0.978261            0.021739
#
#       college_passes_defended_avg  college_fumbles_recov_avg  \
# 1858                     0.260000                   0.100000
# 1861                     0.024390                   0.000000
# 1867                     0.047619                   0.261905
# 1868                     0.222222                   0.063492
# 1876                     0.173913                   0.043478
#
#       college_fumbles_recov_yds_avg  college_fumbles_recov_td_avg  \
# 1858                       0.420000                      0.000000
# 1861                       0.000000                      0.000000
# 1867                       0.023810                      0.047619
# 1868                       0.000000                      0.000000
# 1876                       0.847826                      0.000000
#
#       college_fumbles_forced_avg  drafted  position_group  power_5
# 1858                    0.120000     True              LB     True
# 1861                    0.097561     True              LB     True
# 1867                    0.000000     True              LB     True
# 1868                    0.095238     True              LB    False
# 1876                    0.108696     True              LB     True
#
# [5 rows x 72 columns]
#
# DB 2024 Data
#                                                     URL            School  \
# 1848  https://www.sports-reference.com/cfb/players/a...          Kentucky
# 1855  https://www.sports-reference.com/cfb/players/c...       Wake Forest
# 1856  https://www.sports-reference.com/cfb/players/c...               USC
# 1857  https://www.sports-reference.com/cfb/players/c...        Notre Dame
# 1860  https://www.sports-reference.com/cfb/players/c...  Washington State
#
#         Conf     G  college_solo_tackles  college_assisted_tackle  \
# 1848     SEC  38.0                  55.0                     27.0
# 1855     ACC  36.0                  92.0                     28.0
# 1856  Pac-12  38.0                  96.0                     54.0
# 1857     Ind  47.0                  59.0                     32.0
# 1860  Pac-12  33.0                  70.0                     32.0
#
#       college_total_tackles  college_tackles_for_loss  college_sk  \
# 1848                   82.0                       4.0         0.0
# 1855                  120.0                       3.0         0.0
# 1856                  150.0                       0.0         0.0
# 1857                   91.0                      10.0         0.0
# 1860                  102.0                       7.0         0.0
#
#       college_int  ...  college_int_yds_avg  college_int_td_avg  \
# 1848          0.0  ...             0.000000            0.263158
# 1855          3.0  ...             0.833333            0.000000
# 1856          9.0  ...             5.605263            0.052632
# 1857          2.0  ...             0.680851            0.000000
# 1860          3.0  ...             0.848485            0.000000
#
#       college_passes_defended_avg  college_fumbles_recov_avg  \
# 1848                     0.000000                   0.000000
# 1855                     0.722222                   0.055556
# 1856                     0.394737                   0.000000
# 1857                     0.361702                   0.021277
# 1860                     0.545455                   0.030303
#
#       college_fumbles_recov_yds_avg  college_fumbles_recov_td_avg  \
# 1848                            0.0                           0.0
# 1855                            0.0                           0.0
# 1856                            0.0                           0.0
# 1857                            0.0                           0.0
# 1860                            0.0                           0.0
#
#       college_fumbles_forced_avg  drafted  position_group  power_5
# 1848                    0.000000     True              DB     True
# 1855                    0.055556     True              DB     True
# 1856                    0.000000     True              DB     True
# 1857                    0.063830     True              DB    False
# 1860                    0.090909     True              DB     True
#
# [5 rows x 72 columns]

# %%
import pandas as pd
import joblib
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# Load the saved model
xgb_model = joblib.load('xgb_lb_model.pkl')

# Define features and make sure to use the same columns as when training the model
lb_features = ['combine_shuttle', 'combine_broad', 'combine_vertical', 'combine_forty',
               'college_total_tackles_avg', 'college_tackles_for_loss_avg', 'college_assisted_tackle_avg',
               'college_int_avg', 'college_int_yds_avg', 'college_solo_tackles_avg']

# Prepare the feature matrix for the 2024 LB data (you might need to do feature engineering, like imputation, on the 2024 data)
X_lb_2024 = lb_2024_df[lb_features]  # Ensure lb_2024_df is already defined

# Apply the same imputer used during training
imputer = IterativeImputer(random_state=42)
X_lb_2024_imputed = pd.DataFrame(imputer.fit_transform(X_lb_2024), columns=lb_features)

# Predict the carav_per_year for 2024 players using the trained model
lb_2024_df['predicted_carav_per_year'] = xgb_model.predict(X_lb_2024_imputed)

# Sort by predicted carav_per_year and select the top 10 predicted players
top_10_lb_predicted = lb_2024_df.sort_values(by='predicted_carav_per_year', ascending=False).head(10)

# Now for the scout top 10, we'll sort by 'draft_pick' and take the top 10 based on draft pick
top_10_lb_scout = lb_2024_df.sort_values(by='draft_pick').head(10)

# Merge the model and scout selections to compare the two
common_top_10_lb = pd.merge(top_10_lb_predicted, top_10_lb_scout, on='player_name', suffixes=('_model', '_scout'))

# Display the top 10 players based on the model, scouts, and the common players
print("\nTop 10 Players Predicted by Model for LB in 2024:")
print(top_10_lb_predicted[['player_name']])

print("\nTop 10 Players Selected by Scouts for LB in 2024:")
print(top_10_lb_scout[['player_name']])

print("\nCommon Top 10 Players in Both Model and Scout Selections for LB in 2024:")
print(common_top_10_lb[['player_name']])

# Save the results to CSV files
top_10_lb_predicted.to_csv('top_10_lb_predicted_2024.csv', index=False)
top_10_lb_scout.to_csv('top_10_lb_scout_2024.csv', index=False)
common_top_10_lb.to_csv('common_top_10_lb_2024.csv', index=False)

print("\nCSV files have been saved!")
# Out:
# Top 10 Players Predicted by Model for LB in 2024:
#                player_name
# 1933            Myles Cole
# 1898  Jeremiah Trotter Jr.
# 1892           Jaylan Ford
# 1955         Tyrice Knight
# 1938         Payton Wilson
# 1858           Cedric Gray
# 1903          Jordan Magee
# 1950        Trevin Wallace
# 1861        Chris Braswell
# 1946         Tatum Bethune
#
# Top 10 Players Selected by Scouts for LB in 2024:
#           player_name
# 1867    Dallas Turner
# 1877  Edgerrin Cooper
# 1861   Chris Braswell
# 1906    Junior Colson
# 1950   Trevin Wallace
# 1923    Marist Liufau
# 1956    Ty'Ron Hopper
# 1938    Payton Wilson
# 1858      Cedric Gray
# 1955    Tyrice Knight
#
# Common Top 10 Players in Both Model and Scout Selections for LB in 2024:
#       player_name
# 0   Tyrice Knight
# 1   Payton Wilson
# 2     Cedric Gray
# 3  Trevin Wallace
# 4  Chris Braswell
#
# CSV files have been saved!
# C:\Users\benfi\AppData\Local\Temp/ipykernel_72452/384381905.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lb_2024_df['predicted_carav_per_year'] = xgb_model.predict(X_lb_2024_imputed)
